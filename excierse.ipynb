# %%
print('Hello woel')
# Out:
# Hello woel

# %%
pip install matplotlib
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
square = [i**2 for i in range(10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
import pymatgen.core
print(pymatgen.core.__version__)
# Out:
# 2023.12.18

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

solvent = pd.read_excel("solvent structure of Na+.xlsx", sheet_name= "Na-EC-1X")
print(solvent.head())
# Out:
#           Name    E(Hatree)   E1(Hatree)     HOMO     LUMO  EgX100  \
# 0  Na-3EC-1DEC -1612.147960 -1449.811304 -0.05061 -0.02988  -2.073
# 1  Na-4EC-1DEC -1954.635879 -1792.283944 -0.04938 -0.03565  -1.373
# 2  Na-5EC-1DEC -2297.122785 -2134.769441 -0.04636 -0.03067  -1.569
# 3  Na-3EC-1DMC -1533.492751 -1371.149704 -0.05786 -0.03264  -2.522
# 4  Na-4EC-1DMC -1875.959701 -1713.607267 -0.04960 -0.03293  -1.667
#
#    desolvent E(kcal/mol)         μ  Na-O(in埃)  Na-O(out埃)  Weak solvation
# 0             -31.284640  4.084297    2.17388     6.99918             NaN
# 1             -40.872212  1.397175    2.19260     6.96540             1.0
# 2             -41.756360  5.774366    2.19619     6.78871             1.0
# 3             -35.294993  1.616962    2.17332     5.64742             NaN
# 4             -41.185335  2.433277    2.19259     5.73099             1.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

solvent = pd.read_excel("solvent structure of Na+.xlsx", sheet_name= "Na-EC-1X")
print(solvent.head())

df = solvent.melt(id_vars='Name', var_name='HOMO',  value_name='Weak solvent',)
df = df.dropna()
df1 = solvent.iloc[:,[0,2,4]]

print(solvent.isnull().values.sum())
print(solvent.iloc[:,[2,4]])      #取两列数据
print(df1)

sns.set()
solvent.hist("HOMO")
sns.displot(solvent['HOMO'])
plt.show()

# sns.jointplot(x='HUMO', y='LUMO',data= solvent, kind='kde')
# ax = sns.lineplot(solvent['HOMO'],solvent['LUMO'])
# ax.set_title('obtrital')
# plt.show()
# Out:
#           Name    E(Hatree)   E1(Hatree)     HOMO     LUMO  EgX100  \
# 0  Na-3EC-1DEC -1612.147960 -1449.811304 -0.05061 -0.02988  -2.073
# 1  Na-4EC-1DEC -1954.635879 -1792.283944 -0.04938 -0.03565  -1.373
# 2  Na-5EC-1DEC -2297.122785 -2134.769441 -0.04636 -0.03067  -1.569
# 3  Na-3EC-1DMC -1533.492751 -1371.149704 -0.05786 -0.03264  -2.522
# 4  Na-4EC-1DMC -1875.959701 -1713.607267 -0.04960 -0.03293  -1.667
#
#    desolvent E(kcal/mol)         μ  Na-O(in埃)  Na-O(out埃)  Weak solvation
# 0             -31.284640  4.084297    2.17388     6.99918             NaN
# 1             -40.872212  1.397175    2.19260     6.96540             1.0
# 2             -41.756360  5.774366    2.19619     6.78871             1.0
# 3             -35.294993  1.616962    2.17332     5.64742             NaN
# 4             -41.185335  2.433277    2.19259     5.73099             1.0
# 6
#      E1(Hatree)     LUMO
# 0  -1449.811304 -0.02988
# 1  -1792.283944 -0.03565
# 2  -2134.769441 -0.03067
# 3  -1371.149704 -0.03264
# 4  -1713.607267 -0.03293
# 5  -2056.089365 -0.02957
# 6   -993.896690 -0.03032
# 7  -1336.377876 -0.03251
# 8  -1678.840643 -0.02955
# 9  -2021.314790 -0.03244
# 10 -1410.475692 -0.03315
# 11 -1752.933969 -0.03341
# 12 -2095.422999 -0.02941
# 13 -1409.282147 -0.02982
# 14 -1751.756741 -0.03042
# 15 -2094.233618 -0.03176
# 16 -1368.682140 -0.03012
# 17 -1711.161170 -0.02895
# 18 -2053.636416 -0.02996
#            Name   E1(Hatree)     LUMO
# 0   Na-3EC-1DEC -1449.811304 -0.02988
# 1   Na-4EC-1DEC -1792.283944 -0.03565
# 2   Na-5EC-1DEC -2134.769441 -0.03067
# 3   Na-3EC-1DMC -1371.149704 -0.03264
# 4   Na-4EC-1DMC -1713.607267 -0.03293
# 5   Na-5EC-1DMC -2056.089365 -0.02957
# 6   Na-2EC-1DME  -993.896690 -0.03032
# 7   Na-3EC-1DME -1336.377876 -0.03251
# 8   Na-4EC-1DME -1678.840643 -0.02955
# 9   Na-5EC-1DME -2021.314790 -0.03244
# 10  Na-3EC-1EMC -1410.475692 -0.03315
# 11  Na-4EC-1EMC -1752.933969 -0.03341
# 12  Na-5EC-1EMC -2095.422999 -0.02941
# 13   Na-3EC-1PC -1409.282147 -0.02982
# 14   Na-4EC-1PC -1751.756741 -0.03042
# 15   Na-5EC-1PC -2094.233618 -0.03176
# 16   Na-3EC-1VC -1368.682140 -0.03012
# 17   Na-4EC-1VC -1711.161170 -0.02895
# 18   Na-5EC-1VC -2053.636416 -0.02996

# %%
import random
from sklearn import  svm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

solvent = pd.read_excel("solvent structure of Na+.xlsx", sheet_name= "Na-EC-1X")
print(solvent.head())
x = solvent.iloc[:,2]
y = solvent.iloc[:,2]


# 向量内积函数
def dot(m, n):
    return (sum(m_i * n_i for m_i, n_i in zip(m, n)))


# 平均值函数
def mean(x):
    return (sum(x) / len(x))


# 计算协方差
####-----要计算一个序列方差只需covariance(x,x)即可---####
def de_mean(x):
    x_bar = mean(x)

    return ([x_i - x_bar for x_i in x])


def covariance(x, y):
    return (dot(de_mean(x), de_mean(y)) / (len(x) - 1))


# 计算相关系数
import math


def correlation(x, y):
    s_x = math.sqrt(covariance(x, x))
    s_y = math.sqrt(covariance(y, y))

    return (covariance(x, y) / (s_x * s_y))


# -----------------【最小二乘法】线性回归系数求法--------------
def line_coef(x, y):
    s1 = covariance(x, x) * (len(x) - 1)
    s2 = dot(y, de_mean(x))
    beta = s2 / s1
    alpha = mean(y) - beta * mean(x)

    return (alpha, beta)

# *********实验************
# 由于暂时没有实验数据，这里生成【随机干扰】数据
import random as rdm

solvent = pd.read_excel("solvent structure of Na+.xlsx", sheet_name= "Na-EC-1X")
print(solvent.head())
x = solvent.iloc[:,2]
y = solvent.iloc[:,2]
# from numpy import *
# def ran(a1, a2, x):
#     return [a1 + a2 * x_i + 2.5 * random.random() for x_i in x]


a1 = 1.5
a2 = 2.5
# x = range(20)
# y = ran(a1, a2, x)
# 线性拟合
alpha, beta = line_coef(x, y)
print('*------------最小二乘法-------------*')
print('系数为：', alpha, beta)

# 可视化
import matplotlib.pyplot as plt

# 开一个【2x2】的图像窗口
# plt.subplot(221)
plt.figure(1)
plt.scatter(x, y, marker='*', color='b')
plt.xlabel('E')
plt.ylabel('HUMO')
plt.title('Linear Fit')
# 拟合直线
plt.plot(x, [alpha + beta * x_i for x_i in x], color='orange')
# plt.subplot(222)
plt.show()


# 误差分析
# -----主要考察:(1)误差平方和;(2)R方（越大拟合得越好）
def err(alpha, beta, x, y):  # 返回每个实际y值与拟合值差向量
    return ([y_i - (alpha + beta * x_i) for x_i, y_i in zip(x, y)])


def error_total(alpha, beta, x, y):
    y1 = err(alpha, beta, x, y)

    return (dot(y1, y1))

print('误差为：', error_total(alpha, beta, x, y))


# 计算R方

def r_square(alpha, beta, x, y):
    return (1 - error_total(alpha, beta, x, y) / covariance(y, y))


R_square = r_square(alpha, beta, x, y)
print('R方：', R_square)
if (R_square > 0.95):
    print('在0.05置信水平下，该线性拟合不错!')
else:
    print('在0.05置信水平下，该线性拟合效果不佳!')
# Out:
#           Name    E(Hatree)   E1(Hatree)     HOMO     LUMO  EgX100  \
# 0  Na-3EC-1DEC -1612.147960 -1449.811304 -0.05061 -0.02988  -2.073
# 1  Na-4EC-1DEC -1954.635879 -1792.283944 -0.04938 -0.03565  -1.373
# 2  Na-5EC-1DEC -2297.122785 -2134.769441 -0.04636 -0.03067  -1.569
# 3  Na-3EC-1DMC -1533.492751 -1371.149704 -0.05786 -0.03264  -2.522
# 4  Na-4EC-1DMC -1875.959701 -1713.607267 -0.04960 -0.03293  -1.667
#
#    desolvent E(kcal/mol)         μ  Na-O(in埃)  Na-O(out埃)  Weak solvation
# 0             -31.284640  4.084297    2.17388     6.99918             NaN
# 1             -40.872212  1.397175    2.19260     6.96540             1.0
# 2             -41.756360  5.774366    2.19619     6.78871             1.0
# 3             -35.294993  1.616962    2.17332     5.64742             NaN
# 4             -41.185335  2.433277    2.19259     5.73099             1.0
#           Name    E(Hatree)   E1(Hatree)     HOMO     LUMO  EgX100  \
# 0  Na-3EC-1DEC -1612.147960 -1449.811304 -0.05061 -0.02988  -2.073
# 1  Na-4EC-1DEC -1954.635879 -1792.283944 -0.04938 -0.03565  -1.373
# 2  Na-5EC-1DEC -2297.122785 -2134.769441 -0.04636 -0.03067  -1.569
# 3  Na-3EC-1DMC -1533.492751 -1371.149704 -0.05786 -0.03264  -2.522
# 4  Na-4EC-1DMC -1875.959701 -1713.607267 -0.04960 -0.03293  -1.667
#
#    desolvent E(kcal/mol)         μ  Na-O(in埃)  Na-O(out埃)  Weak solvation
# 0             -31.284640  4.084297    2.17388     6.99918             NaN
# 1             -40.872212  1.397175    2.19260     6.96540             1.0
# 2             -41.756360  5.774366    2.19619     6.78871             1.0
# 3             -35.294993  1.616962    2.17332     5.64742             NaN
# 4             -41.185335  2.433277    2.19259     5.73099             1.0
# *------------最小二乘法-------------*
# 系数为： -2.2737367544323206e-12 0.9999999999999987
# 误差为： 3.360421238496675e-24
# R方： 1.0
# 在0.05置信水平下，该线性拟合不错!
